# %% [markdown]
# #**Theoretical Questions:**

# %% [markdown]
# #1. What is hypothesis testing in statistics?
# - Statistical hypothesis testing is a method used to determine if there's enough evidence in a sample to draw conclusions about a population, involving formulating hypotheses (null and alternative), collecting data, and assessing the evidence to decide whether to reject or fail to reject the null hypothesis.

# %% [markdown]
# #2. What is the Null hypothesis, and how does it differ from the alternative hypothesis?
# - The null hypothesis is a fundamental concept in statistical hypothesis testing. It represents the default or baseline assumption, suggesting that there is no effect, no difference, or no relationship between variables in a population. For example, it might state, "This treatment has no impact."
#
#  In contrast, the alternative hypothesis is what researchers aim to support, proposing that there is an effect, a difference, or a relationship between variables. For instance, it might argue, "This treatment significantly improves outcomes."
#
#  To summarize:
#
#  - Null hypothesis (H₀): The assumption of no change or effect.
#
#  - Alternative hypothesis (H₁): The assumption of a real change or effect.

# %% [markdown]
# #3. What is the significance level in hypothesis testing, and why is it important?
# - The significance level, often denoted as α (alpha), is a threshold used in hypothesis testing to decide whether to reject the null hypothesis. It represents the probability of making a Type I error—rejecting the null hypothesis when it is actually true. Commonly used significance levels are 0.05, 0.01, or 0.10.
#
#  **Why is it important?**
#  Decision-making: It provides a criterion for determining whether the observed data is sufficiently unlikely under the null hypothesis.
#
#  - **Balancing errors:** Lower significance levels reduce the risk of Type I errors but increase the risk of Type II errors (failing to reject a false null hypothesis).
#
#  - **Scientific rigor:** Setting a significance level in advance prevents bias in interpreting results.

# %% [markdown]
# #4. What does a P-value represent in hypothesis testing?
#  - A P-value is a measure used in hypothesis testing to determine the strength of evidence against the null hypothesis. It represents the probability of observing the test statistic (or something more extreme) under the assumption that the null hypothesis is true`1` `2`.

# %% [markdown]
# #5. How do you interpret the P-value in hypothesis testing?
#  - Interpreting the P-value in hypothesis testing involves understanding its role as a measure of evidence against the null hypothesis. Here's how to interpret it:
#
#   - **Small P-value (e.g., ≤ 0.05):** Indicates strong evidence against the null hypothesis, suggesting it may be rejected. For instance, if the P-value is 0.03, there's only a 3% probability of observing the data (or something more extreme) if the null hypothesis is true.
#
#   - **Large P-value (e.g., > 0.05):** Suggests weak evidence against the null hypothesis, meaning it may not be rejected. This implies the data is consistent with the null hypothesis.

# %% [markdown]
# #6. What are Type 1 and Type 2 errors in hypothesis testing?
#  - Type 1 error(False Positive):
#    - It occurs when the null hypothesis is rejected even though it is true.
#    - The probability of making a Type 1 error is equal to the significance level (α).
#
#  - Type 2 error(False Negative):
#    - It happens when the null hypothesis is not rejected even though it is false.
#    - The probability of making a Type 2 error is donated by β.

# %% [markdown]
# #7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#  - Difference between a one-tailed test and a two-tailed test in hypothesis testing:
#
#   **One-Tailed Test**:
#   - Tests whether the effect or relationship exits in a specific direction(e.g., greater than or less than a certain value).
#   - It located in only one tail of the distribution(either the left tail or the right tail).
#
#   **Two-Tailed Test**:
#   - Tests whether the effect or relationship exits in either direction(e.g., different from a certain value, whether it's greater or smaller).
#   - It splits between two tails of the distribution.

# %% [markdown]
# #8. What is the Z-test, and when is it used in hypothesis testing?
#  - The **Z-test** is a statistical test used in hypothesis testing to determine whether there is a significant difference between sample data and population parameters, assuming the data follows a normal distribution.
#
#   **When is it used?**
#
# 1. **Known Population Standard Deviation:** The Z-test is applied when the population standard deviation is known.
#
# 2. **Large Sample Size:** It is typically used when the sample size is large (n ≥ 30).
#
# 3. **Comparing Means:** It can test whether:
#
#   - A sample mean differs from a population mean (one-sample Z-test).
#
#   - Two sample means differ (two-sample Z-test).
#
# 4. **Proportions:** It can also compare proportions between two groups.

# %% [markdown]
# #9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#  - The Z-score is calculated using the formula:
#
#   𝑍
#   =
#   (
#   𝑋
#   −
#   𝜇
#   )
#   𝜎
#
# Where:
#
#   - X is the observed value.
#
#   - μ is the population mean.
#
#   - σ is the population standard deviation.
#
# **What does it represent?**
#
# The Z-score measures how many standard deviations an observed value is from the population mean. In hypothesis testing, it helps determine whether the observed data is significantly different from the null hypothesis. A high absolute Z-score indicates that the data is unlikely under the null hypothesis, leading to its rejection.

# %% [markdown]
# #10. What is the T-distribution, and when should it be used instead of the normal distribution?
#  - The T-distribution (or Student's T-distribution) is a probability distribution used in statistics, particularly in hypothesis testing and confidence interval estimation. It is similar to the normal distribution but has heavier tails, meaning it accounts for more variability in the data.
#
# **When should it be used instead of the normal distribution?**
#
# 1. **Small Sample Sizes:** When the sample size is small (typically n < 30), the T-distribution is more appropriate because it adjusts for the increased uncertainty in estimating the population standard deviation.
#
# 2. **Unknown Population Standard Deviation:** If the population standard deviation is unknown and must be estimated from the sample data, the T-distribution is used.
#
# 3. **Robustness:** It is more robust for small datasets or when the data slightly deviates from normality.

# %% [markdown]
# #11. What is the difference between a Z-test and a T-test?
#  - Difference between a Z-test and a T-test:
#
# **Z-test:**
#
#  - **Population Variance:** It requires the population variance to be known.
#  - **Sample Size:**  It is suitable for large sample sizes (n ≥ 30).
#  - **Distribution:** It is based on the standard normal distribution.
#  - **Use Case:** Comparing sample means to population means or proportions when the population variance is known.
#
# **T-test:**
#
#  - **Population Variance:** It is used when the population variance is unknown and estimated from the sample.
#  - **Sample Size:** Ideal for small sample sizes (n < 30).
#  - **Distribution:** It is based on the T-distribution, which accounts for more variability in small samples.
#  - **Use Case:** Comparing means between two groups or a sample mean to a known value.

# %% [markdown]
# #12. What is the T-test, and how is it used in hypothesis testing?
#  - The T-test is a statistical method used in hypothesis testing to determine whether there is a significant difference between the means of two groups or between a sample mean and a known value. It is particularly useful when the sample size is small and the population standard deviation is unknown.
#
# **How is it used?**
#
# 1. **Formulate Hypotheses:** Define the null hypothesis (no difference) and the alternative hypothesis (a significant difference).
#
# 2. **Calculate the T-statistic:** Use the sample data to compute the T-statistic, which measures the difference relative to the variability in the data.
#
# 3. **Compare to Critical Value or P-value:** It determine whether the T-statistic falls within the critical region or whether the P-value is below the significance level (α).
#
# 4. **Make a Decision:** It reject or fail to reject the null hypothesis based on the results.

# %% [markdown]
# #13. What is the relationship between Z-test and T-test in hypothesis testing?
#  - The Z-test and T-test are closely related statistical methods used in hypothesis testing, but they differ in their assumptions and applications. Here's how they are connected:
#
# 1. **Purpose:** Both tests aim to determine whether there is a significant difference between sample data and population parameters or between two groups.
#
# 2. **Distribution:** The Z-test relies on the standard normal distribution, while the T-test uses the T-distribution, which accounts for more variability in small samples.
#
# 3. **Sample Size:** The Z-test is typically used for large samples (n ≥ 30), whereas the T-test is preferred for small samples (n < 30).
#
# 4. **Population Variance:** The Z-test requires the population variance to be known, while the T-test is used when the population variance is unknown and estimated from the sample.

# %% [markdown]
# #14. What is a confidence interval, and how is it used to interpret statistical results?
#  - A **confidence interval** is a range of values derived from sample data that is likely to contain the true population parameter (e.g., mean or proportion). It provides a measure of uncertainty in an estimate and is expressed with a confidence level, such as 95% or 99%.-
#
# **How It's Used:**
# 1. **Interpretation:** A 95% confidence interval means that if we were to take 100 different samples and calculate intervals for each, approximately 95 of those intervals would contain the true population parameter.
#
# 2. **Decision-Making:** Confidence intervals help researchers assess the reliability of their estimates and make informed decisions.
#
# 3. **Precision:** Narrow intervals indicate more precise estimates, while wider intervals suggest greater uncertainty.

# %% [markdown]
# #15. What is the margin of error, and how does it affect the confidence interval?
#  - The margin of error quantifies the uncertainty in a statistical estimate, representing the maximum expected difference between the sample statistic and the true population parameter. It is influenced by factors like sample size, variability, and confidence level.
#
# **How It Affects Confidence Interval:**
#
# 1. **Width of Interval:** The margin of error determines the range of the confidence interval. A larger margin of error results in a wider interval, indicating greater uncertainty, while a smaller margin of error leads to a narrower interval, suggesting more precision.
# 2. **Confidence Level:** Higher confidence levels (e.g., 99% vs. 95%) increase the margin of error, as they require a broader interval to ensure the true parameter is captured.
#
# 3. **Sample Size:** Larger sample sizes reduce the margin of error, leading to more precise confidence intervals.

# %% [markdown]
# #16.  How is Bayes' Theorem used in statistics, and what is its significance?
#  - Bayes' Theorem is a fundamental concept in statistics that provides a way to update the probability of a hypothesis based on new evidence. It is expressed mathematically as:
#
#  𝑃
#  (
#  𝐴
#  ∣
#  𝐵
#  )
#  =
#  𝑃
#  (
#  𝐵
#  ∣
#  𝐴
#  )
#  ⋅
#  𝑃
#  (
#  𝐴
#  )
#  𝑃
#  (
#  𝐵
#  )
#
# **Usage in Statistics:**
#
# 1. **Updating Beliefs:** Bayes' Theorem allows statisticians to revise prior probabilities (initial beliefs) into posterior probabilities (updated beliefs) after observing new data.
#
# 2. **Decision-Making:** It is widely used in fields like medicine, finance, and machine learning to make informed decisions based on probabilities.
#
# 3. **Classification:** In machine learning, it forms the basis of algorithms like Naive Bayes classifiers.
#
# **Significance:**
#
# 1. **Flexibility:** It accommodates uncertainty and incorporates prior knowledge, making it versatile for various applications.
#
# 2. **Real-World Applications:** From diagnosing diseases to spam email filtering, Bayes' Theorem is integral to solving practical problems.
#
# 3. **Foundation of Bayesian Statistics:** It underpins Bayesian inference, a powerful approach to statistical analysis.

# %% [markdown]
# #17. What is the Chi-square distribution, and when is it used?
#  - The Chi-square distribution is a continuous probability distribution that arises when the sum of the squares of independent standard normal variables is calculated. It is widely used in statistics for hypothesis testing and analyzing categorical data.
#
# **Key Characteristics:**
# 1. **Degree of Freedom**
# 2. **Non-Negative Values**
# 3. **Skewness**

# %% [markdown]
# #18. What is the Chi-square goodness of fit test, and how is it applied?
#  - The Chi-square goodness of fit test is a statistical method used to determine whether observed data matches an expected distribution. It helps assess whether a categorical variable follows a hypothesized distribution.
#
# **Key Steps in Application:**
#
# 1. **Define Hypotheses:**
#
# - **Null Hypothesis (𝐻0):** The observed data fits the expected distribution.
# - **Alternative Hypothesis (𝐻1):** The observed data does not fit the expected distribution.
#
# 2. **Calculate the Test Statistic:**
# - Use the formula: $$\chi^2 = \sum \frac{(O - E)^2}{E}$$ where 𝑂 is the observed frequency, and 𝐸is the expected frequency.
#
# 3. **Determine Degrees of Freedom:**
# - Degrees of freedom (𝑑𝑓) = Number of categories - 1.
#
# 4. **Compare with Critical Value:**
# - Compare the calculated 𝜒 2 value with the critical value from the Chi-square distribution table at a chosen significance level (e.g., 0.05).
#
# 5. **Make a Decision:**
# - If 𝜒 2 exceeds the critical value, reject the null hypothesis, indicating the data does not fit the expected distribution.

# %% [markdown]
# #19. What is the F-distribution, and when is it used in hypothesis testing?
#  - The F-distribution is a continuous probability distribution that arises frequently in statistical analysis, particularly in hypothesis testing. It is defined by two sets of degrees of freedom: one for the numerator and one for the denominator. The F-distribution is positively skewed and becomes more symmetric as the degrees of freedom increase.
#
# **Applications in Hypothesis Testing:**
#
# 1. **Comparing Variances:** The F-test uses the F-distribution to compare the variances of two populations. For example, it helps determine if two datasets have equal variability.
#
# 2. **Analysis of Variance (ANOVA):** The F-distribution is central to ANOVA, which tests whether the means of multiple groups are significantly different by analyzing the ratio of between-group variance to within-group variance.
#
# 3. **Regression Analysis:** It is used to test the overall significance of a regression model by comparing the explained variance to the unexplained variance.

# %% [markdown]
# #20. What is an ANOVA test, and what are its assumptions?
#  - The ANOVA test (Analysis of Variance) is a statistical method used to compare the means of three or more groups to determine if there are significant differences among them. It analyzes the variability within and between groups to assess whether observed differences are due to chance or reflect true effects.
#
# **Assumptions of ANOVA:**
#
# 1. **Normality:** The data in each group should be drawn from a normally distributed population.
#
# 2. **Homogeneity of Variances:** The variances of the populations being compared should be equal.
#
# 3. **Independence:** Observations within and between groups must be independent of each other.

# %% [markdown]
# #21. What are the different types of ANOVA tests?
#  - ANOVA tests come in various types, each suited to specific scenarios:
#
# 1. **One-Way ANOVA:** Compares the means of three or more groups based on a single independent variable. For example, testing the effect of different fertilizers on plant growth.
#
# 2. **Two-Way ANOVA:** Examines the impact of two independent variables simultaneously, including their interaction effects. For instance, analyzing how teaching methods and class timings affect student performance.
#
# 3. **Repeated Measures ANOVA:** Used when the same subjects are tested under different conditions or time points, controlling for individual variability. For example, measuring the effect of a drug on patients over multiple time intervals.

# %% [markdown]
# #22. What is the F-test, and how does it relate to hypothesis testing?
#  - The F-test is a statistical test used to compare the variances of two populations or samples. It is based on the F-distribution and is commonly applied in hypothesis testing to assess whether the variability between groups is significantly different.
#
# **Key Features of the F-Test:**
#
# 1. **Purpose:** It evaluates whether two variances are equal (null hypothesis) or not (alternative hypothesis).
#
# 2. **Formula:** The F-statistic is calculated as the ratio of two sample variances: $$F = \frac{s_12}{s_22}$$ where
# 𝑠
# 1
# 2
#  and
# 𝑠
# 2
# 2 are the variances of the two samples.
#
# 3. **Degrees of Freedom:** The F-distribution depends on two degrees of freedom—one for the numerator and one for the denominator.
#
# **Applications in Hypothesis Testing:**
#
# 1. **Variance Comparison:** To test if two populations have equal variances.
#
# 2. **ANOVA (Analysis of Variance):** The F-test is central to ANOVA, where it determines whether the means of multiple groups are significantly different by comparing between-group and within-group variances.
#
# 3. **Regression Analysis:** It assesses the overall significance of a regression model by comparing explained and unexplained variances.

# %% [markdown]
# #**Practical Questions:**

# %% [markdown]
# #1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

# %%
import scipy.stats as stats

sample_mean = float(input("Enter the sample mean: "))
population_mean = float(input("Enter the population mean: "))
population_std_dev = float(input("Enter the population standard deviation: "))
sample_size = int(input("Enter the sample size: "))

z_score = (sample_mean - population_mean) / (population_std_dev / (sample_size ** 0.5))

p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.5f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Enter the sample mean: 1000
# Enter the population mean: 65
# Enter the population standard deviation: 500
# Enter the sample size: 2000
# Z-score: 83.63
# P-value: 0.00000
# Reject the null hypothesis: There is a significant difference.

# %% [markdown]
# #2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import numpy as np
import scipy.stats as stats

np.random.seed(42)
sample_size = 30
population_mean = 75
population_std_dev = 10
random_data = np.random.normal(loc=population_mean, scale=population_std_dev, size=sample_size)

sample_mean = np.mean(random_data)
z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.5f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Sample Mean: 73.12
# Z-score: -1.03
# P-value: 0.30276
# Fail to reject the null hypothesis: No significant difference.

# %% [markdown]
# #3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean?

# %%
import numpy as np
import scipy.stats as stats

def one_sample_z_test(sample, population_mean, population_std_dev):
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))

    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    return z_score, p_value

np.random.seed(42)
sample = np.random.normal(loc=75, scale=10, size=30)
population_mean = 75
population_std_dev = 10

z_score, p_value = one_sample_z_test(sample, population_mean, population_std_dev)

print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.5f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Z-score: -1.03
# P-value: 0.30276
# Fail to reject the null hypothesis: No significant difference.

# %% [markdown]
# #4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def two_tailed_z_test(sample, population_mean, population_std_dev, alpha=0.05):
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))

    critical_value = stats.norm.ppf(1 - alpha / 2)

    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    return z_score, p_value, critical_value

np.random.seed(42)
sample_size = 30
population_mean = 75
population_std_dev = 10
random_sample = np.random.normal(loc=population_mean, scale=population_std_dev, size=sample_size)

z_score, p_value, critical_value = two_tailed_z_test(random_sample, population_mean, population_std_dev)

x = np.linspace(-4, 4, 1000)
y = stats.norm.pdf(x)

plt.plot(x, y, label="Standard Normal Distribution")
plt.axvline(-critical_value, color='red', linestyle='--', label=f"Critical Value (-{critical_value:.2f})")
plt.axvline(critical_value, color='red', linestyle='--', label=f"Critical Value ({critical_value:.2f})")
plt.axvline(z_score, color='blue', linestyle='-', label=f"Z-score ({z_score:.2f})")
plt.fill_between(x, y, where=(x <= -critical_value) | (x >= critical_value), color='red', alpha=0.3, label="Rejection Region")
plt.title("Decision Region for Two-Tailed Z-Test")
plt.legend()
plt.xlabel("Z-values")
plt.ylabel("Probability Density")
plt.show()

print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.5f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference found.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Z-score: -1.03
# P-value: 0.30276
# Fail to reject the null hypothesis: No significant difference.

# %% [markdown]
# #5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def visualize_type1_and_type2_errors(mu0, mu1, sigma, sample_size, alpha):

    standard_error = sigma / np.sqrt(sample_size)

    z_critical = stats.norm.ppf(1 - alpha)
    critical_value = mu0 + z_critical * standard_error

    x = np.linspace(mu0 - 4*sigma, mu1 + 4*sigma, 1000)
    y_null = stats.norm.pdf(x, loc=mu0, scale=standard_error)
    y_alternate = stats.norm.pdf(x, loc=mu1, scale=standard_error)

    plt.figure(figsize=(10, 6))
    plt.plot(x, y_null, label="Null Hypothesis (H0)", color='blue')
    plt.plot(x, y_alternate, label="Alternate Hypothesis (H1)", color='green')

    plt.fill_between(x, y_null, where=(x >= critical_value), color='red', alpha=0.4, label="Type 1 Error (α)")

    beta_region = x <= critical_value
    plt.fill_between(x, y_alternate, where=beta_region, color='orange', alpha=0.4, label="Type 2 Error (β)")

    plt.axvline(x=critical_value, color='black', linestyle='--', label=f"Critical Value = {critical_value:.2f}")

    plt.title("Type 1 and Type 2 Errors in Hypothesis Testing")
    plt.xlabel("Test Statistic")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid()
    plt.show()

    beta = stats.norm.cdf(critical_value, loc=mu1, scale=standard_error)
    print(f"Type 2 Error (β): {beta:.4f}")
    print(f"Power of the Test (1 - β): {1 - beta:.4f}")

mu0 = 100
mu1 = 105
sigma = 15
sample_size = 30
alpha = 0.05

visualize_type1_and_type2_errors(mu0, mu1, sigma, sample_size, alpha)
# Out:
# Type 2 Error (β): 0.4282
# Power of the Test (1 - β): 0.5718

# %% [markdown]
# #6. Write a Python program to perform an independent T-test and interpret the results.

# %%
import numpy as np
from scipy.stats import ttest_ind

def independent_t_test(sample1, sample2, alpha=0.05):
    t_stat, p_value = ttest_ind(sample1, sample2, equal_var=False)

    print(f"T-statistic: {t_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: The means of the two samples are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the sample means.")

np.random.seed(42)
sample1 = np.random.normal(loc=75, scale=10, size=30)
sample2 = np.random.normal(loc=80, scale=12, size=30)

independent_t_test(sample1, sample2)
# Out:
# T-statistic: -2.0720
# P-value: 0.0429
# Reject the null hypothesis: The means of the two samples are significantly different.

# %% [markdown]
# #7. Perform a paired sample T-test using Python and visualize the comparison results.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def paired_sample_t_test(sample1, sample2, alpha=0.05):
    t_stat, p_value = stats.ttest_rel(sample1, sample2)

    print(f"T-statistic: {t_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: Significant difference between paired samples.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between paired samples.")

np.random.seed(42)
sample1 = np.random.normal(loc=75, scale=10, size=30)
sample2 = np.random.normal(loc=78, scale=10, size=30)

paired_sample_t_test(sample1, sample2)

plt.figure(figsize=(8, 5))
plt.scatter(range(len(sample1)), sample1, label="Sample 1 (Before)", color="blue", alpha=0.7)
plt.scatter(range(len(sample2)), sample2, label="Sample 2 (After)", color="green", alpha=0.7)
plt.plot(range(len(sample1)), sample1, color="blue", alpha=0.5, linestyle="--")
plt.plot(range(len(sample2)), sample2, color="green", alpha=0.5, linestyle="--")
plt.title("Paired Samples Comparison")
plt.xlabel("Index")
plt.ylabel("Values")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# T-statistic: -1.6350
# P-value: 0.1128
# Fail to reject the null hypothesis: No significant difference between paired samples.

# %% [markdown]
# #8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
import scipy.stats as stats

def z_test(sample, population_mean, population_std_dev):
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))
    return z_score, p_value

def t_test(sample, population_mean):
    t_stat, p_value = stats.ttest_1samp(sample, population_mean)
    return t_stat, p_value

np.random.seed(42)
population_mean = 75
population_std_dev = 10
sample_size = 20
sample = np.random.normal(loc=population_mean, scale=population_std_dev, size=sample_size)

z_score, z_p_value = z_test(sample, population_mean, population_std_dev)

t_stat, t_p_value = t_test(sample, population_mean)

print("Results of Z-test:")
print(f"Z-score: {z_score:.4f}")
print(f"P-value: {z_p_value:.4f}")
print("\nResults of T-test:")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {t_p_value:.4f}")

if z_p_value < 0.05:
    print("\nZ-test: Reject the null hypothesis. Significant difference found.")
else:
    print("\nZ-test: Fail to reject the null hypothesis. No significant difference.")

if t_p_value < 0.05:
    print("T-test: Reject the null hypothesis. Significant difference found.")
else:
    print("T-test: Fail to reject the null hypothesis. No significant difference.")
# Out:
# Results of Z-test:
# Z-score: -0.7661
# P-value: 0.4436
#
# Results of T-test:
# T-statistic: -0.7980
# P-value: 0.4348
#
# Z-test: Fail to reject the null hypothesis. No significant difference.
# T-test: Fail to reject the null hypothesis. No significant difference.

# %% [markdown]
# #9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
import numpy as np
from scipy.stats import t

def confidence_interval(sample, confidence_level=0.95):
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    degrees_of_freedom = sample_size - 1
    t_critical = t.ppf((1 + confidence_level) / 2, df=degrees_of_freedom)

    margin_of_error = t_critical * standard_error

    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

np.random.seed(42)
sample_data = np.random.normal(loc=75, scale=10, size=30)
confidence_level = 0.95

lower_bound, upper_bound = confidence_interval(sample_data, confidence_level)
print(f"{confidence_level*100:.0f}% Confidence Interval: [{lower_bound:.2f}, {upper_bound:.2f}]")
# Out:
# 95% Confidence Interval: [69.76, 76.48]

# %% [markdown]
# #10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import numpy as np
from scipy.stats import t

def calculate_margin_of_error(sample, confidence_level=0.95):
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)
    sample_size = len(sample)

    standard_error = sample_std / np.sqrt(sample_size)

    degrees_of_freedom = sample_size - 1
    t_critical = t.ppf((1 + confidence_level) / 2, df=degrees_of_freedom)

    margin_of_error = t_critical * standard_error

    return margin_of_error

np.random.seed(42)
sample_data = np.random.normal(loc=75, scale=10, size=30)
confidence_level = 0.95

margin_of_error = calculate_margin_of_error(sample_data, confidence_level)
print(f"Margin of Error for {confidence_level*100:.0f}% confidence level: {margin_of_error:.2f}")
# Out:
# Margin of Error for 95% confidence level: 3.36

# %% [markdown]
# #11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
def bayesian_inference(prior, likelihood, marginal_likelihood):
    posterior = (likelihood * prior) / marginal_likelihood
    return posterior

prior = 0.3
likelihood = 0.8
marginal_likelihood = 0.5

posterior = bayesian_inference(prior, likelihood, marginal_likelihood)
print(f"Posterior Probability: {posterior:.4f}")
# Out:
# Posterior Probability: 0.4800

# %% [markdown]
# #12. Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

data = np.array([[120, 90, 40], [110, 95, 45]])
categories = ['Male', 'Female']
columns = ['Republican', 'Democrat', 'Independent']

df = pd.DataFrame(data, index=categories, columns=columns)
print("Contingency Table:")
print(df)

chi2_stat, p_value, dof, expected = chi2_contingency(data)

print("\nChi-square Test Results:")
print(f"Chi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of Freedom: {dof}")
print("\nExpected Frequencies:")
print(pd.DataFrame(expected, index=categories, columns=columns))

alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis: The two variables are not independent.")
else:
    print("\nFail to reject the null hypothesis: The two variables are independent.")
# Out:
# Contingency Table:
#         Republican  Democrat  Independent
# Male           120        90           40
# Female         110        95           45
#
# Chi-square Test Results:
# Chi-square Statistic: 0.8640
# P-value: 0.6492
# Degrees of Freedom: 2
#
# Expected Frequencies:
#         Republican  Democrat  Independent
# Male         115.0      92.5         42.5
# Female       115.0      92.5         42.5
#
# Fail to reject the null hypothesis: The two variables are independent.

# %% [markdown]
# #13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

# %%
import numpy as np

def calculate_expected_frequencies(observed, hypothesized_proportions):
    total_observed = np.sum(observed)

    expected = total_observed * hypothesized_proportions
    return expected

observed = np.array([50, 30, 20])
hypothesized_proportions = np.array([0.4, 0.4, 0.2])

expected = calculate_expected_frequencies(observed, hypothesized_proportions)
print("Observed Frequencies:", observed)
print("Expected Frequencies:", expected)
# Out:
# Observed Frequencies: [50 30 20]
# Expected Frequencies: [40. 40. 20.]

# %% [markdown]
# #14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
import numpy as np
from scipy.stats import chisquare

observed = np.array([50, 30, 20])
expected = np.array([40, 40, 20])

chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"Chi-square Statistic: {chi_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The observed data does not fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed data fits the expected distribution.")
# Out:
# Chi-square Statistic: 5.0000
# P-value: 0.0821
# Fail to reject the null hypothesis: The observed data fits the expected distribution.

# %% [markdown]
# #15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

degrees_of_freedom = [2, 5, 10, 20]
x = np.linspace(0, 50, 500)

plt.figure(figsize=(10, 6))
for df in degrees_of_freedom:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f"df={df}")

plt.title("Chi-Square Distribution for Different Degrees of Freedom")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #16. Implement an F-test using Python to compare the variances of two random samples.

# %%
import numpy as np
from scipy.stats import f

def f_test(sample1, sample2, alpha=0.05):
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)

    if var1 > var2:
        f_stat = var1 / var2
        df1, df2 = len(sample1) - 1, len(sample2) - 1
    else:
        f_stat = var2 / var1
        df1, df2 = len(sample2) - 1, len(sample1) - 1

    p_value = 1 - f.cdf(f_stat, df1, df2)
    p_value = p_value * 2

    print(f"F-statistic: {f_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: The variances are significantly different.")
    else:
        print("Fail to reject the null hypothesis: The variances are not significantly different.")

np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=10, size=30)
sample2 = np.random.normal(loc=50, scale=15, size=30)

f_test(sample1, sample2)
# Out:
# F-statistic: 2.4082
# P-value: 0.0209
# Reject the null hypothesis: The variances are significantly different.

# %% [markdown]
# #17. Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results.

# %%
import numpy as np
import pandas as pd
from scipy.stats import f_oneway

np.random.seed(42)
group_1 = np.random.normal(loc=50, scale=5, size=30)
group_2 = np.random.normal(loc=55, scale=5, size=30)
group_3 = np.random.normal(loc=60, scale=5, size=30)

f_stat, p_value = f_oneway(group_1, group_2, group_3)

print("One-Way ANOVA Results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Significant differences exist among the group means.")
else:
    print("Fail to reject the null hypothesis: No significant differences among the group means.")
# Out:
# One-Way ANOVA Results:
# F-statistic: 40.9756
# P-value: 0.0000
# Reject the null hypothesis: Significant differences exist among the group means.

# %% [markdown]
# #18. Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.

# %%
import numpy as np
import pandas as pd
from scipy.stats import f_oneway
import matplotlib.pyplot as plt

np.random.seed(42)
group_A = np.random.normal(loc=50, scale=5, size=30)
group_B = np.random.normal(loc=55, scale=5, size=30)
group_C = np.random.normal(loc=60, scale=5, size=30)

f_stat, p_value = f_oneway(group_A, group_B, group_C)

print("One-Way ANOVA Results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Significant differences exist among the group means.")
else:
    print("Fail to reject the null hypothesis: No significant differences among the group means.")

data = pd.DataFrame({
    'Group': ['A'] * len(group_A) + ['B'] * len(group_B) + ['C'] * len(group_C),
    'Value': np.concatenate([group_A, group_B, group_C])
})

plt.figure(figsize=(8, 6))
data.boxplot(column='Value', by='Group', grid=False)
plt.title("Group-wise Comparison of Values")
plt.suptitle("")
plt.xlabel("Groups")
plt.ylabel("Values")
plt.grid(True)
plt.show()
# Out:
# One-Way ANOVA Results:
# F-statistic: 40.9756
# P-value: 0.0000
# Reject the null hypothesis: Significant differences exist among the group means.

# %% [markdown]
# #19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.

# %%
import numpy as np
import pandas as pd
from scipy.stats import shapiro, levene
import matplotlib.pyplot as plt

def check_anova_assumptions(data, groups_column, response_column):
    grouped_data = data.groupby(groups_column)[response_column]

    print("Normality Test Results:")
    for group_name, group_data in grouped_data:
        stat, p_value = shapiro(group_data)
        print(f"Group '{group_name}': W-statistic={stat:.4f}, P-value={p_value:.4f}")
        if p_value < 0.05:
            print(f"  -> Group '{group_name}' does not follow a normal distribution (P < 0.05).")
        else:
            print(f"  -> Group '{group_name}' follows a normal distribution (P >= 0.05).")

    group_values = [group_data.values for _, group_data in grouped_data]
    stat, p_value = levene(*group_values)
    print("\nEqual Variance Test Results (Levene's Test):")
    print(f"Levene's Statistic={stat:.4f}, P-value={p_value:.4f}")
    if p_value < 0.05:
        print("  -> Variances are not equal among groups (P < 0.05).")
    else:
        print("  -> Variances are equal among groups (P >= 0.05).")

    print("\nIndependence Assumption:")
    print("Independence must be ensured during data collection. This assumption cannot be tested using statistical methods.")

    plt.figure(figsize=(8, 6))
    data.boxplot(column=response_column, by=groups_column)
    plt.title("Boxplot of Response by Groups")
    plt.suptitle("")
    plt.xlabel(groups_column)
    plt.ylabel(response_column)
    plt.grid(True)
    plt.show()

np.random.seed(42)
data = pd.DataFrame({
    'Group': np.repeat(['A', 'B', 'C'], 20),
    'Response': np.concatenate([
        np.random.normal(50, 5, 20),
        np.random.normal(55, 5, 20),
        np.random.normal(60, 5, 20)
    ])
})

check_anova_assumptions(data, groups_column='Group', response_column='Response')
# Out:
# Normality Test Results:
# Group 'A': W-statistic=0.9746, P-value=0.8479
#   -> Group 'A' follows a normal distribution (P >= 0.05).
# Group 'B': W-statistic=0.9706, P-value=0.7676
#   -> Group 'B' follows a normal distribution (P >= 0.05).
# Group 'C': W-statistic=0.9472, P-value=0.3271
#   -> Group 'C' follows a normal distribution (P >= 0.05).
#
# Equal Variance Test Results (Levene's Test):
# Levene's Statistic=0.1143, P-value=0.8922
#   -> Variances are equal among groups (P >= 0.05).
#
# Independence Assumption:
# Independence must be ensured during data collection. This assumption cannot be tested using statistical methods.

# %% [markdown]
# #20.Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns

np.random.seed(42)
data = pd.DataFrame({
    'Factor1': np.repeat(['A', 'B', 'C'], 20),
    'Factor2': np.tile(np.repeat(['X', 'Y'], 10), 3),
    'Response': np.random.normal(loc=50, scale=5, size=60)
})
model = ols('Response ~ Factor1 + Factor2 + Factor1:Factor2', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print("Two-Way ANOVA Results:\n")
print(anova_table)

plt.figure(figsize=(8, 6))
sns.pointplot(data=data, x='Factor1', y='Response', hue='Factor2', dodge=True, markers=['o', 's'], capsize=0.1)
plt.title("Interaction Plot for Factor1 and Factor2")
plt.xlabel("Factor1 Levels")
plt.ylabel("Mean Response")
plt.legend(title="Factor2 Levels")
plt.grid(True)
plt.show()
# Out:
# Two-Way ANOVA Results:
#
#                      sum_sq    df         F    PR(>F)
# Factor1           14.522061   2.0  0.398223  0.673468
# Factor2           31.880544   1.0  1.748451  0.191645
# Factor1:Factor2  186.464251   2.0  5.113208  0.009255
# Residual         984.613819  54.0       NaN       NaN

# %% [markdown]
# #21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

degrees_of_freedom = [(5, 10), (10, 15), (20, 30)]
x = np.linspace(0, 5, 500)

plt.figure(figsize=(10, 6))
for df_n, df_d in degrees_of_freedom:
    y = f.pdf(x, df_n, df_d)
    plt.plot(x, y, label=f"df_n={df_n}, df_d={df_d}")

plt.title("F-Distribution for Different Degrees of Freedom")
plt.xlabel("Value of F-statistic")
plt.ylabel("Probability Density")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.

# %%
import numpy as np
import pandas as pd
from scipy.stats import f_oneway
import matplotlib.pyplot as plt

np.random.seed(42)
group_1 = np.random.normal(loc=50, scale=5, size=30)
group_2 = np.random.normal(loc=55, scale=5, size=30)
group_3 = np.random.normal(loc=60, scale=5, size=30)

f_stat, p_value = f_oneway(group_1, group_2, group_3)

print("One-Way ANOVA Results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Significant differences exist among the group means.")
else:
    print("Fail to reject the null hypothesis: No significant differences among the group means.")

data = pd.DataFrame({
    'Group': ['Group 1'] * len(group_1) + ['Group 2'] * len(group_2) + ['Group 3'] * len(group_3),
    'Value': np.concatenate([group_1, group_2, group_3])
})

plt.figure(figsize=(8, 6))
data.boxplot(column='Value', by='Group', grid=False)
plt.title("Group-wise Comparison of Values")
plt.suptitle("")
plt.xlabel("Groups")
plt.ylabel("Values")
plt.show()
# Out:
# One-Way ANOVA Results:
# F-statistic: 40.9756
# P-value: 0.0000
# Reject the null hypothesis: Significant differences exist among the group means.

# %% [markdown]
# #23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.

# %%
import numpy as np
from scipy.stats import ttest_1samp

np.random.seed(42)
population_mean = 50
population_std_dev = 10
sample_size = 30

sample_data = np.random.normal(loc=population_mean, scale=population_std_dev, size=sample_size)

hypothesized_mean = 52
t_statistic, p_value = ttest_1samp(sample_data, popmean=hypothesized_mean)

print("Hypothesis Testing Results:")
print(f"Sample Mean: {np.mean(sample_data):.2f}")
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean significantly differs from the hypothesized mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the sample and hypothesized mean.")
# Out:
# Hypothesis Testing Results:
# Sample Mean: 48.12
# T-statistic: -2.3622
# P-value: 0.0251
# Reject the null hypothesis: The sample mean significantly differs from the hypothesized mean.

# %% [markdown]
# #24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.

# %%
import numpy as np
from scipy.stats import chi2

def test_population_variance(sample, hypothesized_variance, alpha=0.05):
    sample_size = len(sample)
    sample_variance = np.var(sample, ddof=1)

    chi_square_stat = (sample_size - 1) * sample_variance / hypothesized_variance

    df = sample_size - 1

    critical_value_low = chi2.ppf(alpha / 2, df)
    critical_value_high = chi2.ppf(1 - alpha / 2, df)

    p_value = 2 * min(chi2.cdf(chi_square_stat, df), 1 - chi2.cdf(chi_square_stat, df))

    print(f"Sample Variance: {sample_variance:.4f}")
    print(f"Chi-square Statistic: {chi_square_stat:.4f}")
    print(f"Degrees of Freedom: {df}")
    print(f"Critical Values: ({critical_value_low:.4f}, {critical_value_high:.4f})")
    print(f"P-value: {p_value:.4f}")

    if chi_square_stat < critical_value_low or chi_square_stat > critical_value_high:
        print("Reject the null hypothesis: The variance significantly differs from the hypothesized variance.")
    else:
        print("Fail to reject the null hypothesis: No significant difference in variance.")

np.random.seed(42)
sample = np.random.normal(loc=50, scale=10, size=30)
hypothesized_variance = 100

test_population_variance(sample, hypothesized_variance)
# Out:
# Sample Variance: 81.0012
# Chi-square Statistic: 23.4903
# Degrees of Freedom: 29
# Critical Values: (16.0471, 45.7223)
# P-value: 0.4927
# Fail to reject the null hypothesis: No significant difference in variance.

# %% [markdown]
# #25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.

# %%
import numpy as np
from scipy.stats import norm

def z_test_proportions(successes1, size1, successes2, size2, alpha=0.05):
    p1 = successes1 / size1
    p2 = successes2 / size2

    p_pool = (successes1 + successes2) / (size1 + size2)

    standard_error = np.sqrt(p_pool * (1 - p_pool) * (1 / size1 + 1 / size2))

    z_score = (p1 - p2) / standard_error

    p_value = 2 * (1 - norm.cdf(abs(z_score)))

    print(f"Proportion 1: {p1:.4f}")
    print(f"Proportion 2: {p2:.4f}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: The proportions are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the proportions.")

successes1 = 45
size1 = 100
successes2 = 30
size2 = 90

z_test_proportions(successes1, size1, successes2, size2)
# Out:
# Proportion 1: 0.4500
# Proportion 2: 0.3333
# Z-score: 1.6427
# P-value: 0.1004
# Fail to reject the null hypothesis: No significant difference between the proportions.

# %% [markdown]
# #26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.

# %%
import numpy as np
from scipy.stats import f
import matplotlib.pyplot as plt

def f_test(sample1, sample2, alpha=0.05):
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)

    f_stat = var1 / var2 if var1 >= var2 else var2 / var1
    df1 = len(sample1) - 1
    df2 = len(sample2) - 1

    critical_value_low = f.ppf(alpha / 2, df1, df2)
    critical_value_high = f.ppf(1 - alpha / 2, df1, df2)

    p_value = 2 * min(f.cdf(f_stat, df1, df2), 1 - f.cdf(f_stat, df1, df2))

    return f_stat, p_value, critical_value_low, critical_value_high, df1, df2

np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=5, size=30)
sample2 = np.random.normal(loc=60, scale=10, size=30)

alpha = 0.05
f_stat, p_value, critical_value_low, critical_value_high, df1, df2 = f_test(sample1, sample2, alpha)

print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of Freedom: df1={df1}, df2={df2}")
print(f"Critical Values: ({critical_value_low:.4f}, {critical_value_high:.4f})")

if f_stat < critical_value_low or f_stat > critical_value_high:
    print("Reject the null hypothesis: Variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference in variances.")

x = np.linspace(0, 5, 500)
y = f.pdf(x, df1, df2)
plt.plot(x, y, label=f"F-distribution (df1={df1}, df2={df2})")
plt.axvline(f_stat, color='blue', linestyle='--', label=f"F-statistic ({f_stat:.4f})")
plt.axvline(critical_value_low, color='red', linestyle='--', label=f"Critical Value Low ({critical_value_low:.4f})")
plt.axvline(critical_value_high, color='red', linestyle='--', label=f"Critical Value High ({critical_value_high:.4f})")
plt.fill_between(x, y, where=(x < critical_value_low) | (x > critical_value_high), color='red', alpha=0.2, label="Rejection Region")
plt.title("F-Test: Comparing Variances")
plt.xlabel("F-value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid()
plt.show()
# Out:
# F-statistic: 4.2812
# P-value: 0.0002
# Degrees of Freedom: df1=29, df2=29
# Critical Values: (0.4760, 2.1010)
# Reject the null hypothesis: Variances are significantly different.

# %% [markdown]
# #27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

# %%
import numpy as np
from scipy.stats import chisquare

np.random.seed(42)
observed = np.random.randint(20, 50, size=5)

total_observed = np.sum(observed)

expected = np.array([total_observed / 5] * 5)

chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print("Chi-square Goodness-of-Fit Test Results:")
print(f"Observed Frequencies: {observed}")
print(f"Expected Frequencies: {expected}")
print(f"Chi-square Statistic: {chi_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The observed data does not fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed data fits the expected distribution.")
# Out:
# Chi-square Goodness-of-Fit Test Results:
# Observed Frequencies: [26 39 48 34 30]
# Expected Frequencies: [35.4 35.4 35.4 35.4 35.4]
# Chi-square Statistic: 8.2260
# P-value: 0.0836
# Fail to reject the null hypothesis: The observed data fits the expected distribution.
